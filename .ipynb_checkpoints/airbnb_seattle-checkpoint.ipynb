# %% [markdown]
# ### Airbnb Seattle

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
import seaborn as sns
# %matplotlib inline

df0=pd.read_csv('./calendar.csv')
df1=pd.read_csv('./listings.csv')
df2=pd.read_csv('./reviews.csv')

# %%
df0.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  object
#  2   available   1393570 non-null  object
#  3   price       934542 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %%
df0.listing_id.value_counts()
# Out:
# 6752031     365
# 7404370     365
# 1259305     365
# 4672934     365
# 10310373    365
#            ...
# 9999759     365
# 9048029     365
# 8441477     365
# 7984550     365
# 9484823     365
# Name: listing_id, Length: 3818, dtype: int64

# %%
df0.date=pd.to_datetime(df0.date)

# %%
df0.price=df0['price'].str.extract('(\d+)').astype(float)

# %%
df0.available=df0.available.replace(['t', 'f'], [True, False])

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   listing_id  1393570 non-null  int64
#  1   date        1393570 non-null  datetime64[ns]
#  2   available   1393570 non-null  bool
#  3   price       934542 non-null   float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1)
# memory usage: 33.2 MB

# %%
df0.head()
# Out:
#    listing_id       date  available  price
# 0      241032 2016-01-04       True   85.0
# 1      241032 2016-01-05       True   85.0
# 2      241032 2016-01-06      False    NaN
# 3      241032 2016-01-07      False    NaN
# 4      241032 2016-01-08      False    NaN

# %%
df0.isnull().sum()
# Out:
# listing_id         0
# date               0
# available          0
# price         459028
# dtype: int64

# %%
df0.groupby(['date'])['price'].mean().plot();
plt.title('Daily Average Price in 2016');
plt.ylabel('Average Price / US$');
plt.xlabel('Date');

# %%
df0.groupby(['date'])['available'].agg('mean').plot();

# %%
df_priceave=df0.copy()

# %%
df_priceave=df_priceave[['date','price','available']]

# %%
df_priceave.groupby(['date']).agg('mean').plot();

# %%
rng=pd.period_range('2016-01-01', '2016-12-31', freq='M')

# %%
rng
# Out:
# PeriodIndex(['2016-01', '2016-02', '2016-03', '2016-04', '2016-05', '2016-06',
#              '2016-07', '2016-08', '2016-09', '2016-10', '2016-11', '2016-12'],
#             dtype='period[M]', freq='M')

# %%
daily_ave=df0.groupby(['date'])['price'].mean()
daily_ave
# Out:
# date
# 2016-01-04    122.085879
# 2016-01-05    120.681307
# 2016-01-06    120.928258
# 2016-01-07    120.958896
# 2016-01-08    127.640853
#                  ...
# 2016-12-29    136.759083
# 2016-12-30    143.454225
# 2016-12-31    144.422525
# 2017-01-01    137.443190
# 2017-01-02    134.853026
# Name: price, Length: 365, dtype: float64

# %%
df_priceave.query("'20160106'<=date<='20160115'")['price'].mean()
# Out:
# 121.58147845619767

# %% [markdown]
# ## df1

# %%
df1.head()
# Out:
#         id                           listing_url       scrape_id last_scraped  \
# 0   241032   https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1   953595   https://www.airbnb.com/rooms/953595  20160104002432   2016-01-04
# 2  3308979  https://www.airbnb.com/rooms/3308979  20160104002432   2016-01-04
# 3  7421966  https://www.airbnb.com/rooms/7421966  20160104002432   2016-01-04
# 4   278830   https://www.airbnb.com/rooms/278830  20160104002432   2016-01-04
#
#                                   name  \
# 0         Stylish Queen Anne Apartment
# 1   Bright & Airy Queen Anne Apartment
# 2  New Modern House-Amazing water view
# 3                   Queen Anne Chateau
# 4       Charming craftsman 3 bdm house
#
#                                              summary  \
# 0                                                NaN
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                NaN
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Chemically sensitive? We've removed the irrita...                none
# 2  New modern house built in 2013.  Spectacular s...                none
# 3  A charming apartment that sits atop Queen Anne...                none
# 4  Cozy family craftman house in beautiful neighb...                none
#
#                                neighborhood_overview  ... review_scores_value  \
# 0                                                NaN  ...                10.0
# 1  Queen Anne is a wonderful, truly functional vi...  ...                10.0
# 2  Upper Queen Anne is a charming neighborhood fu...  ...                10.0
# 3                                                NaN  ...                 NaN
# 4  We are in the beautiful neighborhood of Queen ...  ...                 9.0
#
#   requires_license license jurisdiction_names instant_bookable  \
# 0                f     NaN         WASHINGTON                f
# 1                f     NaN         WASHINGTON                f
# 2                f     NaN         WASHINGTON                f
# 3                f     NaN         WASHINGTON                f
# 4                f     NaN         WASHINGTON                f
#
#   cancellation_policy  require_guest_profile_picture  \
# 0            moderate                              f
# 1              strict                              t
# 2              strict                              f
# 3            flexible                              f
# 4              strict                              f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              2
# 1                                t                              6
# 2                                f                              2
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              4.07
# 1              1.48
# 2              1.15
# 3               NaN
# 4              0.89
#
# [5 rows x 92 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
#  11  transit                           2884 non-null   object
#  12  thumbnail_url                     3498 non-null   object
#  13  medium_url                        3498 non-null   object
#  14  picture_url                       3818 non-null   object
#  15  xl_picture_url                    3498 non-null   object
#  16  host_id                           3818 non-null   int64
#  17  host_url                          3818 non-null   object
#  18  host_name                         3816 non-null   object
#  19  host_since                        3816 non-null   object
#  20  host_location                     3810 non-null   object
#  21  host_about                        2959 non-null   object
#  22  host_response_time                3295 non-null   object
#  23  host_response_rate                3295 non-null   object
#  24  host_acceptance_rate              3045 non-null   object
#  25  host_is_superhost                 3816 non-null   object
#  26  host_thumbnail_url                3816 non-null   object
#  27  host_picture_url                  3816 non-null   object
#  28  host_neighbourhood                3518 non-null   object
#  29  host_listings_count               3816 non-null   float64
#  30  host_total_listings_count         3816 non-null   float64
#  31  host_verifications                3818 non-null   object
#  32  host_has_profile_pic              3816 non-null   object
#  33  host_identity_verified            3816 non-null   object
#  34  street                            3818 non-null   object
#  35  neighbourhood                     3402 non-null   object
#  36  neighbourhood_cleansed            3818 non-null   object
#  37  neighbourhood_group_cleansed      3818 non-null   object
#  38  city                              3818 non-null   object
#  39  state                             3818 non-null   object
#  40  zipcode                           3811 non-null   object
#  41  market                            3818 non-null   object
#  42  smart_location                    3818 non-null   object
#  43  country_code                      3818 non-null   object
#  44  country                           3818 non-null   object
#  45  latitude                          3818 non-null   float64
#  46  longitude                         3818 non-null   float64
#  47  is_location_exact                 3818 non-null   object
#  48  property_type                     3817 non-null   object
#  49  room_type                         3818 non-null   object
#  50  accommodates                      3818 non-null   int64
#  51  bathrooms                         3802 non-null   float64
#  52  bedrooms                          3812 non-null   float64
#  53  beds                              3817 non-null   float64
#  54  bed_type                          3818 non-null   object
#  55  amenities                         3818 non-null   object
#  56  square_feet                       97 non-null     float64
#  57  price                             3818 non-null   object
#  58  weekly_price                      2009 non-null   object
#  59  monthly_price                     1517 non-null   object
#  60  security_deposit                  1866 non-null   object
#  61  cleaning_fee                      2788 non-null   object
#  62  guests_included                   3818 non-null   int64
#  63  extra_people                      3818 non-null   object
#  64  minimum_nights                    3818 non-null   int64
#  65  maximum_nights                    3818 non-null   int64
#  66  calendar_updated                  3818 non-null   object
#  67  has_availability                  3818 non-null   object
#  68  availability_30                   3818 non-null   int64
#  69  availability_60                   3818 non-null   int64
#  70  availability_90                   3818 non-null   int64
#  71  availability_365                  3818 non-null   int64
#  72  calendar_last_scraped             3818 non-null   object
#  73  number_of_reviews                 3818 non-null   int64
#  74  first_review                      3191 non-null   object
#  75  last_review                       3191 non-null   object
#  76  review_scores_rating              3171 non-null   float64
#  77  review_scores_accuracy            3160 non-null   float64
#  78  review_scores_cleanliness         3165 non-null   float64
#  79  review_scores_checkin             3160 non-null   float64
#  80  review_scores_communication       3167 non-null   float64
#  81  review_scores_location            3163 non-null   float64
#  82  review_scores_value               3162 non-null   float64
#  83  requires_license                  3818 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3818 non-null   object
#  86  instant_bookable                  3818 non-null   object
#  87  cancellation_policy               3818 non-null   object
#  88  require_guest_profile_picture     3818 non-null   object
#  89  require_guest_phone_verification  3818 non-null   object
#  90  calculated_host_listings_count    3818 non-null   int64
#  91  reviews_per_month                 3191 non-null   float64
# dtypes: float64(17), int64(13), object(62)
# memory usage: 2.7+ MB

# %%
df1.last_scraped.value_counts()
# Out:
# 2016-01-04    3818
# Name: last_scraped, dtype: int64

# %% [markdown]
# > listings.csv is for the data before 2016-01-04, while calender.csv is in 2016.

# %%
df11=df1.copy()
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 92 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3818 non-null   int64
#  1   listing_url                       3818 non-null   object
#  2   scrape_id                         3818 non-null   int64
#  3   last_scraped                      3818 non-null   object
#  4   name                              3818 non-null   object
#  5   summary                           3641 non-null   object
#  6   space                             3249 non-null   object
#  7   description                       3818 non-null   object
#  8   experiences_offered               3818 non-null   object
#  9   neighborhood_overview             2786 non-null   object
#  10  notes                             2212 non-null   object
#  11  transit                           2884 non-null   object
#  12  thumbnail_url                     3498 non-null   object
#  13  medium_url                        3498 non-null   object
#  14  picture_url                       3818 non-null   object
#  15  xl_picture_url                    3498 non-null   object
#  16  host_id                           3818 non-null   int64
#  17  host_url                          3818 non-null   object
#  18  host_name                         3816 non-null   object
#  19  host_since                        3816 non-null   object
#  20  host_location                     3810 non-null   object
#  21  host_about                        2959 non-null   object
#  22  host_response_time                3295 non-null   object
#  23  host_response_rate                3295 non-null   object
#  24  host_acceptance_rate              3045 non-null   object
#  25  host_is_superhost                 3816 non-null   object
#  26  host_thumbnail_url                3816 non-null   object
#  27  host_picture_url                  3816 non-null   object
#  28  host_neighbourhood                3518 non-null   object
#  29  host_listings_count               3816 non-null   float64
#  30  host_total_listings_count         3816 non-null   float64
#  31  host_verifications                3818 non-null   object
#  32  host_has_profile_pic              3816 non-null   object
#  33  host_identity_verified            3816 non-null   object
#  34  street                            3818 non-null   object
#  35  neighbourhood                     3402 non-null   object
#  36  neighbourhood_cleansed            3818 non-null   object
#  37  neighbourhood_group_cleansed      3818 non-null   object
#  38  city                              3818 non-null   object
#  39  state                             3818 non-null   object
#  40  zipcode                           3811 non-null   object
#  41  market                            3818 non-null   object
#  42  smart_location                    3818 non-null   object
#  43  country_code                      3818 non-null   object
#  44  country                           3818 non-null   object
#  45  latitude                          3818 non-null   float64
#  46  longitude                         3818 non-null   float64
#  47  is_location_exact                 3818 non-null   object
#  48  property_type                     3817 non-null   object
#  49  room_type                         3818 non-null   object
#  50  accommodates                      3818 non-null   int64
#  51  bathrooms                         3802 non-null   float64
#  52  bedrooms                          3812 non-null   float64
#  53  beds                              3817 non-null   float64
#  54  bed_type                          3818 non-null   object
#  55  amenities                         3818 non-null   object
#  56  square_feet                       97 non-null     float64
#  57  price                             3818 non-null   object
#  58  weekly_price                      2009 non-null   object
#  59  monthly_price                     1517 non-null   object
#  60  security_deposit                  1866 non-null   object
#  61  cleaning_fee                      2788 non-null   object
#  62  guests_included                   3818 non-null   int64
#  63  extra_people                      3818 non-null   object
#  64  minimum_nights                    3818 non-null   int64
#  65  maximum_nights                    3818 non-null   int64
#  66  calendar_updated                  3818 non-null   object
#  67  has_availability                  3818 non-null   object
#  68  availability_30                   3818 non-null   int64
#  69  availability_60                   3818 non-null   int64
#  70  availability_90                   3818 non-null   int64
#  71  availability_365                  3818 non-null   int64
#  72  calendar_last_scraped             3818 non-null   object
#  73  number_of_reviews                 3818 non-null   int64
#  74  first_review                      3191 non-null   object
#  75  last_review                       3191 non-null   object
#  76  review_scores_rating              3171 non-null   float64
#  77  review_scores_accuracy            3160 non-null   float64
#  78  review_scores_cleanliness         3165 non-null   float64
#  79  review_scores_checkin             3160 non-null   float64
#  80  review_scores_communication       3167 non-null   float64
#  81  review_scores_location            3163 non-null   float64
#  82  review_scores_value               3162 non-null   float64
#  83  requires_license                  3818 non-null   object
#  84  license                           0 non-null      float64
#  85  jurisdiction_names                3818 non-null   object
#  86  instant_bookable                  3818 non-null   object
#  87  cancellation_policy               3818 non-null   object
#  88  require_guest_profile_picture     3818 non-null   object
#  89  require_guest_phone_verification  3818 non-null   object
#  90  calculated_host_listings_count    3818 non-null   int64
#  91  reviews_per_month                 3191 non-null   float64
# dtypes: float64(17), int64(13), object(62)
# memory usage: 2.7+ MB

# %%
df1['availability_30'].value_counts()
# Out:
# 30    981
# 0     883
# 29    141
# 25    110
# 27    109
# 26    102
# 28     96
# 20     94
# 23     93
# 21     84
# 24     81
# 22     80
# 2      74
# 16     73
# 18     72
# 19     67
# 3      63
# 17     60
# 1      54
# 10     52
# 14     51
# 9      49
# 8      48
# 5      48
# 12     46
# 13     45
# 15     45
# 4      34
# 6      33
# 11     27
# 7      23
# Name: availability_30, dtype: int64

# %%
df11=df11[['id','host_id','host_since','host_is_superhost','property_type',
          'room_type','accommodates','bathrooms','beds','bed_type','amenities',
          'price','weekly_price','monthly_price','security_deposit','cleaning_fee','has_availability',
          'number_of_reviews','first_review','review_scores_rating','review_scores_accuracy',
           'review_scores_cleanliness','review_scores_checkin','review_scores_communication',
          'review_scores_location','review_scores_value','cancellation_policy','reviews_per_month']]

# %%
def to_datetime(columns): 
    df11.columns=pd.to_datetime(columns)
    return

# %%
def to_bool(columns):
    columns=lambda x: x.replace(['t', 'f'], [True, False]).astype(bool)
    return columns

# %%
to_bool(df11.host_is_superhost)
# Out:
# <function __main__.to_bool.<locals>.<lambda>(x)>

# %%
df11.host_is_superhost
# Out:
# 0       f
# 1       t
# 2       f
# 3       f
# 4       f
#        ..
# 3813    f
# 3814    f
# 3815    f
# 3816    f
# 3817    f
# Name: host_is_superhost, Length: 3818, dtype: object

# %%
df11.host_since=pd.to_datetime(df11.host_since)

# %%
df11.host_since.dtypes
# Out:
# dtype('<M8[ns]')

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           3818 non-null   int64
#  1   host_id                      3818 non-null   int64
#  2   host_since                   3816 non-null   datetime64[ns]
#  3   host_is_superhost            3816 non-null   object
#  4   property_type                3817 non-null   object
#  5   room_type                    3818 non-null   object
#  6   accommodates                 3818 non-null   int64
#  7   bathrooms                    3802 non-null   float64
#  8   beds                         3817 non-null   float64
#  9   bed_type                     3818 non-null   object
#  10  amenities                    3818 non-null   object
#  11  price                        3818 non-null   object
#  12  weekly_price                 2009 non-null   object
#  13  monthly_price                1517 non-null   object
#  14  security_deposit             1866 non-null   object
#  15  cleaning_fee                 2788 non-null   object
#  16  has_availability             3818 non-null   object
#  17  number_of_reviews            3818 non-null   int64
#  18  first_review                 3191 non-null   object
#  19  review_scores_rating         3171 non-null   float64
#  20  review_scores_accuracy       3160 non-null   float64
#  21  review_scores_cleanliness    3165 non-null   float64
#  22  review_scores_checkin        3160 non-null   float64
#  23  review_scores_communication  3167 non-null   float64
#  24  review_scores_location       3163 non-null   float64
#  25  review_scores_value          3162 non-null   float64
#  26  cancellation_policy          3818 non-null   object
#  27  reviews_per_month            3191 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(4), object(13)
# memory usage: 835.3+ KB

# %%
df11['first_review']=pd.to_datetime(df11['first_review'])

# %%
df11['host_since'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df11['host_is_superhost']=df11['host_is_superhost'].replace(['t', 'f'], [True, False]).astype(bool)

# %%
df11['has_availability']=df11['has_availability'].replace(['t', 'f'], [True, False]).astype(bool)

# %%
df11.head()
# Out:
#         id   host_id host_since  host_is_superhost property_type  \
# 0   241032    956883 2011-08-11              False     Apartment
# 1   953595   5177328 2013-02-21               True     Apartment
# 2  3308979  16708587 2014-06-12              False         House
# 3  7421966   9851441 2013-11-06              False     Apartment
# 4   278830   1452570 2011-11-29              False         House
#
#          room_type  accommodates  bathrooms  beds  bed_type  ... first_review  \
# 0  Entire home/apt             4        1.0   1.0  Real Bed  ...   2011-11-01
# 1  Entire home/apt             4        1.0   1.0  Real Bed  ...   2013-08-19
# 2  Entire home/apt            11        4.5   7.0  Real Bed  ...   2014-07-30
# 3  Entire home/apt             3        1.0   2.0  Real Bed  ...          NaT
# 4  Entire home/apt             6        2.0   3.0  Real Bed  ...   2012-07-10
#
#   review_scores_rating review_scores_accuracy review_scores_cleanliness  \
# 0                 95.0                   10.0                      10.0
# 1                 96.0                   10.0                      10.0
# 2                 97.0                   10.0                      10.0
# 3                  NaN                    NaN                       NaN
# 4                 92.0                    9.0                       9.0
#
#   review_scores_checkin review_scores_communication  review_scores_location  \
# 0                  10.0                        10.0                     9.0
# 1                  10.0                        10.0                    10.0
# 2                  10.0                        10.0                    10.0
# 3                   NaN                         NaN                     NaN
# 4                  10.0                        10.0                     9.0
#
#    review_scores_value cancellation_policy  reviews_per_month
# 0                 10.0            moderate               4.07
# 1                 10.0              strict               1.48
# 2                 10.0              strict               1.15
# 3                  NaN            flexible                NaN
# 4                  9.0              strict               0.89
#
# [5 rows x 28 columns]

# %%
#prices=['price','weekly_price','monthly_price','security_deposit','cleaning_fee']
#df11[['price','weekly_price','monthly_price','security_deposit','cleaning_fee']]=df11[['price','weekl
df11['price']=df11['price'].str.extract('(\d+)').astype(float)

# %%
df11['monthly_price']=df11['monthly_price'].str.extract('(\d+)').astype(float)

# %%
df11['weekly_price']=df11['weekly_price'].str.extract('(\d+)').astype(float)

# %%
df11['security_deposit']=df11['security_deposit'].str.extract('(\d+)').astype(float)
df11['cleaning_fee']=df11['cleaning_fee'].str.extract('(\d+)').astype(float)

# %%
df11.head()
# Out:
#         id   host_id host_since  host_is_superhost property_type  \
# 0   241032    956883 2011-08-11              False     Apartment
# 1   953595   5177328 2013-02-21               True     Apartment
# 2  3308979  16708587 2014-06-12              False         House
# 3  7421966   9851441 2013-11-06              False     Apartment
# 4   278830   1452570 2011-11-29              False         House
#
#          room_type  accommodates  bathrooms  beds  bed_type  ... first_review  \
# 0  Entire home/apt             4        1.0   1.0  Real Bed  ...   2011-11-01
# 1  Entire home/apt             4        1.0   1.0  Real Bed  ...   2013-08-19
# 2  Entire home/apt            11        4.5   7.0  Real Bed  ...   2014-07-30
# 3  Entire home/apt             3        1.0   2.0  Real Bed  ...          NaT
# 4  Entire home/apt             6        2.0   3.0  Real Bed  ...   2012-07-10
#
#    review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                  95.0                    10.0                       10.0
# 1                  96.0                    10.0                       10.0
# 2                  97.0                    10.0                       10.0
# 3                   NaN                     NaN                        NaN
# 4                  92.0                     9.0                        9.0
#
#    review_scores_checkin  review_scores_communication  review_scores_location  \
# 0                   10.0                         10.0                     9.0
# 1                   10.0                         10.0                    10.0
# 2                   10.0                         10.0                    10.0
# 3                    NaN                          NaN                     NaN
# 4                   10.0                         10.0                     9.0
#
#    review_scores_value cancellation_policy  reviews_per_month
# 0                 10.0            moderate               4.07
# 1                 10.0              strict               1.48
# 2                 10.0              strict               1.15
# 3                  NaN            flexible                NaN
# 4                  9.0              strict               0.89
#
# [5 rows x 28 columns]

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           3818 non-null   int64
#  1   host_id                      3818 non-null   int64
#  2   host_since                   3816 non-null   datetime64[ns]
#  3   host_is_superhost            3818 non-null   bool
#  4   property_type                3817 non-null   object
#  5   room_type                    3818 non-null   object
#  6   accommodates                 3818 non-null   int64
#  7   bathrooms                    3802 non-null   float64
#  8   beds                         3817 non-null   float64
#  9   bed_type                     3818 non-null   object
#  10  amenities                    3818 non-null   object
#  11  price                        3818 non-null   float64
#  12  weekly_price                 2009 non-null   float64
#  13  monthly_price                1517 non-null   float64
#  14  security_deposit             1866 non-null   float64
#  15  cleaning_fee                 2788 non-null   float64
#  16  has_availability             3818 non-null   bool
#  17  number_of_reviews            3818 non-null   int64
#  18  first_review                 3191 non-null   datetime64[ns]
#  19  review_scores_rating         3171 non-null   float64
#  20  review_scores_accuracy       3160 non-null   float64
#  21  review_scores_cleanliness    3165 non-null   float64
#  22  review_scores_checkin        3160 non-null   float64
#  23  review_scores_communication  3167 non-null   float64
#  24  review_scores_location       3163 non-null   float64
#  25  review_scores_value          3162 non-null   float64
#  26  cancellation_policy          3818 non-null   object
#  27  reviews_per_month            3191 non-null   float64
# dtypes: bool(2), datetime64[ns](2), float64(15), int64(4), object(5)
# memory usage: 783.1+ KB

# %%
df11.describe()
# Out:
#                  id       host_id  accommodates    bathrooms         beds  \
# count  3.818000e+03  3.818000e+03   3818.000000  3802.000000  3817.000000
# mean   5.550111e+06  1.578556e+07      3.349398     1.259469     1.735394
# std    2.962660e+06  1.458382e+07      1.977599     0.590369     1.139480
# min    3.335000e+03  4.193000e+03      1.000000     0.000000     1.000000
# 25%    3.258256e+06  3.275204e+06      2.000000     1.000000     1.000000
# 50%    6.118244e+06  1.055814e+07      3.000000     1.000000     1.000000
# 75%    8.035127e+06  2.590309e+07      4.000000     1.000000     2.000000
# max    1.034016e+07  5.320861e+07     16.000000     8.000000    15.000000
#
#             price  weekly_price  monthly_price  security_deposit  \
# count  3818.00000   2009.000000    1517.000000       1866.000000
# mean    127.71451    433.651070      67.986816        247.292069
# std      89.16278    296.675884     225.403680        153.486417
# min       1.00000      1.000000       1.000000          1.000000
# 25%      75.00000    232.000000       1.000000        100.000000
# 50%     100.00000    476.000000       2.000000        200.000000
# 75%     150.00000    650.000000       3.000000        300.000000
# max     999.00000    999.000000     995.000000        995.000000
#
#        cleaning_fee  number_of_reviews  review_scores_rating  \
# count   2788.000000        3818.000000           3171.000000
# mean      61.710904          22.223415             94.539262
# std       48.830341          37.730892              6.606083
# min        5.000000           0.000000             20.000000
# 25%       25.000000           2.000000             93.000000
# 50%       50.000000           9.000000             96.000000
# 75%       83.000000          26.000000             99.000000
# max      300.000000         474.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             3160.000000                3165.000000
# mean                 9.636392                   9.556398
# std                  0.698031                   0.797274
# min                  2.000000                   3.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            3160.000000                  3167.000000
# mean                9.786709                     9.809599
# std                 0.595499                     0.568211
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  reviews_per_month
# count             3163.000000          3162.000000        3191.000000
# mean                 9.608916             9.452245           2.078919
# std                  0.629053             0.750259           1.822348
# min                  4.000000             2.000000           0.020000
# 25%                  9.000000             9.000000           0.695000
# 50%                 10.000000            10.000000           1.540000
# 75%                 10.000000            10.000000           3.000000
# max                 10.000000            10.000000          12.150000

# %%
df11.host_is_superhost.value_counts()
# Out:
# False    3038
# True      780
# Name: host_is_superhost, dtype: int64

# %%
host=df11.groupby(['host_is_superhost'])
host.agg('mean')[['price','number_of_reviews','review_scores_rating','review_scores_communication','review_scores_location']].plot(kind='bar');

# %%
sns.heatmap(df11.corr(), annot=True, fmt='.2f');

# %%
df11.columns
# Out:
# Index(['id', 'host_id', 'host_since', 'host_is_superhost', 'property_type',
#        'room_type', 'accommodates', 'bathrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'weekly_price', 'monthly_price',
#        'security_deposit', 'cleaning_fee', 'has_availability',
#        'number_of_reviews', 'first_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'cancellation_policy',
#        'reviews_per_month'],
#       dtype='object')

# %%
df12=df11[['accommodates', 'price', 'weekly_price', 'monthly_price',
       'security_deposit', 'cleaning_fee', 'number_of_reviews', 'review_scores_rating', 'reviews_per_month']]

# %%
df12.hist();

# %%
sns.heatmap(df12.corr(), annot=True, fmt='.2f');

# %% [markdown]
# > very little information from the above. need to go to the categoricals.

# %% [markdown]
# ### categorical variables

# %%
df_cat=df11.select_dtypes(include=['object'])
df_cat
# Out:
#      property_type        room_type  bed_type  \
# 0        Apartment  Entire home/apt  Real Bed
# 1        Apartment  Entire home/apt  Real Bed
# 2            House  Entire home/apt  Real Bed
# 3        Apartment  Entire home/apt  Real Bed
# 4            House  Entire home/apt  Real Bed
# ...            ...              ...       ...
# 3813         House  Entire home/apt  Real Bed
# 3814     Apartment  Entire home/apt  Real Bed
# 3815         House  Entire home/apt  Real Bed
# 3816   Condominium  Entire home/apt  Real Bed
# 3817     Apartment  Entire home/apt  Real Bed
#
#                                               amenities cancellation_policy
# 0     {TV,"Cable TV",Internet,"Wireless Internet","A...            moderate
# 1     {TV,Internet,"Wireless Internet",Kitchen,"Free...              strict
# 2     {TV,"Cable TV",Internet,"Wireless Internet","A...              strict
# 3     {Internet,"Wireless Internet",Kitchen,"Indoor ...            flexible
# 4     {TV,"Cable TV",Internet,"Wireless Internet",Ki...              strict
# ...                                                 ...                 ...
# 3813  {TV,"Cable TV",Internet,"Wireless Internet","A...              strict
# 3814  {TV,"Cable TV",Internet,"Wireless Internet",Ki...            moderate
# 3815  {"Cable TV","Wireless Internet",Kitchen,"Free ...            moderate
# 3816  {TV,"Wireless Internet",Kitchen,"Free Parking ...            moderate
# 3817  {TV,"Cable TV",Internet,"Wireless Internet",Ki...            flexible
#
# [3818 rows x 5 columns]

# %%
df_cat.property_type.value_counts()
# Out:
# House              1733
# Apartment          1708
# Townhouse           118
# Condominium          91
# Loft                 40
# Bed & Breakfast      37
# Other                22
# Cabin                21
# Camper/RV            13
# Bungalow             13
# Boat                  8
# Tent                  5
# Treehouse             3
# Chalet                2
# Dorm                  2
# Yurt                  1
# Name: property_type, dtype: int64

# %%
df_cat.room_type.value_counts()
# Out:
# Entire home/apt    2541
# Private room       1160
# Shared room         117
# Name: room_type, dtype: int64

# %%
df_cat.bed_type.value_counts()
# Out:
# Real Bed         3657
# Futon              74
# Pull-out Sofa      47
# Airbed             27
# Couch              13
# Name: bed_type, dtype: int64

# %%
df_cat.amenities.value_counts()
# Out:
# {}                                                                                                                                                                                                                                                                                                                                     45
# {Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,Washer,Dryer}                                                                                                                                                                                                                                                 11
# {TV,"Cable TV",Internet,"Wireless Internet",Pool,Kitchen,"Free Parking on Premises",Gym,"Elevator in Building","Hot Tub",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron}                                   10
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Buzzer/Wireless Intercom",Heating,Washer,Dryer,Essentials,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                                                                                                8
# {TV,"Cable TV",Internet,"Wireless Internet","Air Conditioning",Kitchen,"Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo}                                                                                        7
#                                                                                                                                                                                                                                                                                                                                        ..
# {Internet,"Wireless Internet",Kitchen,"Pets live on this property",Cat(s),Heating,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Essentials,Shampoo,"24-Hour Check-in",Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}                                                                          1
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,"Free Parking on Premises",Heating,"Smoke Detector","Fire Extinguisher",Essentials,Shampoo}                                                                                                                                                                                         1
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Gym,"Elevator in Building","Buzzer/Wireless Intercom",Heating,"Family/Kid Friendly",Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector",Essentials,Shampoo}                                                                                                                    1
# {TV,Internet,"Wireless Internet",Kitchen,"Free Parking on Premises","Pets Allowed","Pets live on this property",Dog(s),Cat(s),Heating,"Family/Kid Friendly","Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Safety Card","Fire Extinguisher",Essentials,Shampoo,Hangers,"Hair Dryer",Iron,"Laptop Friendly Workspace"}     1
# {TV,"Cable TV",Internet,"Wireless Internet",Kitchen,Heating,Washer,Dryer,"Smoke Detector","Carbon Monoxide Detector","First Aid Kit","Fire Extinguisher",Shampoo}                                                                                                                                                                       1
# Name: amenities, Length: 3284, dtype: int64

# %%
df_cat.cancellation_policy.value_counts()
# Out:
# strict      1417
# moderate    1251
# flexible    1150
# Name: cancellation_policy, dtype: int64

# %%
df1_2=df11.copy()
df1_2=df1_2.drop('amenities', axis=1)
cat_df=df1_2.select_dtypes(include='object')
cat_cols_list=cat_df.columns

# %%
cat_df.isnull().sum()
# Out:
# property_type          1
# room_type              0
# bed_type               0
# cancellation_policy    0
# dtype: int64

# %%
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3817 non-null   object
#  1   room_type            3818 non-null   object
#  2   bed_type             3818 non-null   object
#  3   cancellation_policy  3818 non-null   object
# dtypes: object(4)
# memory usage: 119.4+ KB

# %%
cat_df=cat_df.dropna(axis=0)

# %%
def create_dummy_df(df, cat_cols, dummy_na):
    for col in cat_cols:
        try:
            df=pd.concat([df.drop(col, axis=1), 
                          pd.get_dummies(df[col], prefix=col, prefix_sep='_',
                                        drop_first=True, dummy_na=dummy_na)], axis=1)
        except:
            continue
    return df

# %%
df_cat_new=create_dummy_df(df1_2, cat_cols_list, dummy_na=False)

# %%
df_cat_new
# Out:
#             id   host_id host_since  host_is_superhost  accommodates  \
# 0       241032    956883 2011-08-11              False             4
# 1       953595   5177328 2013-02-21               True             4
# 2      3308979  16708587 2014-06-12              False            11
# 3      7421966   9851441 2013-11-06              False             3
# 4       278830   1452570 2011-11-29              False             6
# ...        ...       ...        ...                ...           ...
# 3813   8101950  31148752 2015-04-13              False             6
# 3814   8902327  46566046 2015-10-14              False             4
# 3815  10267360  52791370 2015-12-30              False             2
# 3816   9604740  25522052 2015-01-03              False             2
# 3817  10208623  14703116 2014-04-25              False             3
#
#       bathrooms  beds  price  weekly_price  monthly_price  ...  \
# 0           1.0   1.0   85.0           NaN            NaN  ...
# 1           1.0   1.0  150.0           1.0            3.0  ...
# 2           4.5   7.0  975.0           NaN            NaN  ...
# 3           1.0   2.0  100.0         650.0            2.0  ...
# 4           2.0   3.0  450.0           NaN            NaN  ...
# ...         ...   ...    ...           ...            ...  ...
# 3813        2.0   3.0  359.0           NaN            NaN  ...
# 3814        1.0   2.0   79.0           NaN            NaN  ...
# 3815        1.0   1.0   93.0         450.0            NaN  ...
# 3816        1.0   1.0   99.0           NaN            NaN  ...
# 3817        1.5   1.0   87.0           NaN            NaN  ...
#
#       property_type_Treehouse  property_type_Yurt  room_type_Private room  \
# 0                           0                   0                       0
# 1                           0                   0                       0
# 2                           0                   0                       0
# 3                           0                   0                       0
# 4                           0                   0                       0
# ...                       ...                 ...                     ...
# 3813                        0                   0                       0
# 3814                        0                   0                       0
# 3815                        0                   0                       0
# 3816                        0                   0                       0
# 3817                        0                   0                       0
#
#       room_type_Shared room bed_type_Couch  bed_type_Futon  \
# 0                         0              0               0
# 1                         0              0               0
# 2                         0              0               0
# 3                         0              0               0
# 4                         0              0               0
# ...                     ...            ...             ...
# 3813                      0              0               0
# 3814                      0              0               0
# 3815                      0              0               0
# 3816                      0              0               0
# 3817                      0              0               0
#
#       bed_type_Pull-out Sofa  bed_type_Real Bed  cancellation_policy_moderate  \
# 0                          0                  1                             1
# 1                          0                  1                             0
# 2                          0                  1                             0
# 3                          0                  1                             0
# 4                          0                  1                             0
# ...                      ...                ...                           ...
# 3813                       0                  1                             0
# 3814                       0                  1                             1
# 3815                       0                  1                             1
# 3816                       0                  1                             1
# 3817                       0                  1                             0
#
#       cancellation_policy_strict
# 0                              0
# 1                              1
# 2                              1
# 3                              0
# 4                              1
# ...                          ...
# 3813                           1
# 3814                           0
# 3815                           0
# 3816                           0
# 3817                           0
#
# [3818 rows x 46 columns]

# %%
df_cat_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 46 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             3818 non-null   int64
#  1   host_id                        3818 non-null   int64
#  2   host_since                     3816 non-null   datetime64[ns]
#  3   host_is_superhost              3818 non-null   bool
#  4   accommodates                   3818 non-null   int64
#  5   bathrooms                      3802 non-null   float64
#  6   beds                           3817 non-null   float64
#  7   price                          3818 non-null   float64
#  8   weekly_price                   2009 non-null   float64
#  9   monthly_price                  1517 non-null   float64
#  10  security_deposit               1866 non-null   float64
#  11  cleaning_fee                   2788 non-null   float64
#  12  has_availability               3818 non-null   bool
#  13  number_of_reviews              3818 non-null   int64
#  14  first_review                   3191 non-null   datetime64[ns]
#  15  review_scores_rating           3171 non-null   float64
#  16  review_scores_accuracy         3160 non-null   float64
#  17  review_scores_cleanliness      3165 non-null   float64
#  18  review_scores_checkin          3160 non-null   float64
#  19  review_scores_communication    3167 non-null   float64
#  20  review_scores_location         3163 non-null   float64
#  21  review_scores_value            3162 non-null   float64
#  22  reviews_per_month              3191 non-null   float64
#  23  property_type_Bed & Breakfast  3818 non-null   uint8
#  24  property_type_Boat             3818 non-null   uint8
#  25  property_type_Bungalow         3818 non-null   uint8
#  26  property_type_Cabin            3818 non-null   uint8
#  27  property_type_Camper/RV        3818 non-null   uint8
#  28  property_type_Chalet           3818 non-null   uint8
#  29  property_type_Condominium      3818 non-null   uint8
#  30  property_type_Dorm             3818 non-null   uint8
#  31  property_type_House            3818 non-null   uint8
#  32  property_type_Loft             3818 non-null   uint8
#  33  property_type_Other            3818 non-null   uint8
#  34  property_type_Tent             3818 non-null   uint8
#  35  property_type_Townhouse        3818 non-null   uint8
#  36  property_type_Treehouse        3818 non-null   uint8
#  37  property_type_Yurt             3818 non-null   uint8
#  38  room_type_Private room         3818 non-null   uint8
#  39  room_type_Shared room          3818 non-null   uint8
#  40  bed_type_Couch                 3818 non-null   uint8
#  41  bed_type_Futon                 3818 non-null   uint8
#  42  bed_type_Pull-out Sofa         3818 non-null   uint8
#  43  bed_type_Real Bed              3818 non-null   uint8
#  44  cancellation_policy_moderate   3818 non-null   uint8
#  45  cancellation_policy_strict     3818 non-null   uint8
# dtypes: bool(2), datetime64[ns](2), float64(15), int64(4), uint8(23)
# memory usage: 719.7 KB

# %% [markdown]
# ## df2

# %%
df2.head()
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2.groupby(['date']).agg('count')['comments'].plot();

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84849 entries, 0 to 84848
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   listing_id     84849 non-null  int64
#  1   id             84849 non-null  int64
#  2   date           84849 non-null  datetime64[ns]
#  3   reviewer_id    84849 non-null  int64
#  4   reviewer_name  84849 non-null  object
#  5   comments       84831 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 3.9+ MB

# %%
df2.listing_id.value_counts()
# Out:
# 208356     474
# 365550     466
# 25002      404
# 47196      353
# 63308      320
#           ...
# 5992645      1
# 9465815      1
# 2875975      1
# 7873208      1
# 6808970      1
# Name: listing_id, Length: 3191, dtype: int64

# %%
df_cat_new.rename(columns={'id':'listing_id'}, inplace=True)

# %%
df_clean=pd.merge(df_cat_new, df2, how='outer', on='listing_id')

# %%
df_clean.head()
# Out:
#    listing_id  host_id host_since  host_is_superhost  accommodates  bathrooms  \
# 0      241032   956883 2011-08-11              False             4        1.0
# 1      241032   956883 2011-08-11              False             4        1.0
# 2      241032   956883 2011-08-11              False             4        1.0
# 3      241032   956883 2011-08-11              False             4        1.0
# 4      241032   956883 2011-08-11              False             4        1.0
#
#    beds  price  weekly_price  monthly_price  ...  bed_type_Futon  \
# 0   1.0   85.0           NaN            NaN  ...               0
# 1   1.0   85.0           NaN            NaN  ...               0
# 2   1.0   85.0           NaN            NaN  ...               0
# 3   1.0   85.0           NaN            NaN  ...               0
# 4   1.0   85.0           NaN            NaN  ...               0
#
#    bed_type_Pull-out Sofa  bed_type_Real Bed  cancellation_policy_moderate  \
# 0                       0                  1                             1
# 1                       0                  1                             1
# 2                       0                  1                             1
# 3                       0                  1                             1
# 4                       0                  1                             1
#
#   cancellation_policy_strict        id       date  reviewer_id  reviewer_name  \
# 0                          0  682061.0 2011-11-01     479824.0            Bro
# 1                          0  691712.0 2011-11-04     357699.0          Megan
# 2                          0  702999.0 2011-11-08    1285567.0        Marylee
# 3                          0  717262.0 2011-11-14     647857.0         Graham
# 4                          0  730226.0 2011-11-19    1389821.0         Franka
#
#                                             comments
# 0  Excellent all the way around. \r\n\r\nMaija wa...
# 1  Maija's apartment was a wonderful place to sta...
# 2  one of the most pleasant stays i've had in my ...
# 3  Maija's suite is beautiful, cozy and convenien...
# 4  Our stay was short and pleasant. With its own ...
#
# [5 rows x 51 columns]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85476 entries, 0 to 85475
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   listing_id                     85476 non-null  int64
#  1   host_id                        85476 non-null  int64
#  2   host_since                     85474 non-null  datetime64[ns]
#  3   host_is_superhost              85476 non-null  bool
#  4   accommodates                   85476 non-null  int64
#  5   bathrooms                      84863 non-null  float64
#  6   beds                           85475 non-null  float64
#  7   price                          85476 non-null  float64
#  8   weekly_price                   46571 non-null  float64
#  9   monthly_price                  36244 non-null  float64
#  10  security_deposit               42366 non-null  float64
#  11  cleaning_fee                   61675 non-null  float64
#  12  has_availability               85476 non-null  bool
#  13  number_of_reviews              85476 non-null  int64
#  14  first_review                   84849 non-null  datetime64[ns]
#  15  review_scores_rating           84829 non-null  float64
#  16  review_scores_accuracy         84815 non-null  float64
#  17  review_scores_cleanliness      84822 non-null  float64
#  18  review_scores_checkin          84815 non-null  float64
#  19  review_scores_communication    84824 non-null  float64
#  20  review_scores_location         84818 non-null  float64
#  21  review_scores_value            84817 non-null  float64
#  22  reviews_per_month              84849 non-null  float64
#  23  property_type_Bed & Breakfast  85476 non-null  uint8
#  24  property_type_Boat             85476 non-null  uint8
#  25  property_type_Bungalow         85476 non-null  uint8
#  26  property_type_Cabin            85476 non-null  uint8
#  27  property_type_Camper/RV        85476 non-null  uint8
#  28  property_type_Chalet           85476 non-null  uint8
#  29  property_type_Condominium      85476 non-null  uint8
#  30  property_type_Dorm             85476 non-null  uint8
#  31  property_type_House            85476 non-null  uint8
#  32  property_type_Loft             85476 non-null  uint8
#  33  property_type_Other            85476 non-null  uint8
#  34  property_type_Tent             85476 non-null  uint8
#  35  property_type_Townhouse        85476 non-null  uint8
#  36  property_type_Treehouse        85476 non-null  uint8
#  37  property_type_Yurt             85476 non-null  uint8
#  38  room_type_Private room         85476 non-null  uint8
#  39  room_type_Shared room          85476 non-null  uint8
#  40  bed_type_Couch                 85476 non-null  uint8
#  41  bed_type_Futon                 85476 non-null  uint8
#  42  bed_type_Pull-out Sofa         85476 non-null  uint8
#  43  bed_type_Real Bed              85476 non-null  uint8
#  44  cancellation_policy_moderate   85476 non-null  uint8
#  45  cancellation_policy_strict     85476 non-null  uint8
#  46  id                             84849 non-null  float64
#  47  date                           84849 non-null  datetime64[ns]
#  48  reviewer_id                    84849 non-null  float64
#  49  reviewer_name                  84849 non-null  object
#  50  comments                       84831 non-null  object
# dtypes: bool(2), datetime64[ns](3), float64(17), int64(4), object(2), uint8(23)
# memory usage: 19.6+ MB

# %%
df_clean.groupby(['date']).agg('mean')[['price','weekly_price','monthly_price']].plot();

# %%
df_clean.groupby(['date']).agg('count')['host_since'].plot();

# %%
df_clean.groupby(['date']).agg('count')['number_of_reviews'].plot();

# %%
df_clean.groupby(['review_scores_rating']).agg('mean')
# Out:
#                         listing_id       host_id  host_is_superhost  \
# review_scores_rating
# 20.0                  9.183838e+06  4.600524e+07           0.000000
# 40.0                  8.051251e+06  3.152417e+07           0.000000
# 53.0                  4.892529e+06  9.207095e+06           0.000000
# 55.0                  6.370313e+06  3.028359e+07           0.000000
# 57.0                  9.075558e+06  7.237936e+06           0.000000
# 60.0                  7.331098e+06  1.441510e+07           0.095238
# 64.0                  7.071021e+06  3.074414e+06           0.000000
# 65.0                  1.764233e+06  3.074414e+06           0.000000
# 66.0                  2.420875e+06  3.074414e+06           0.000000
# 67.0                  7.953624e+06  3.712627e+07           0.000000
# 68.0                  2.181214e+06  3.009192e+06           0.000000
# 70.0                  3.634177e+06  1.277855e+07           0.000000
# 71.0                  3.111948e+06  8.103196e+06           0.000000
# 72.0                  2.824410e+06  7.768357e+06           0.000000
# 73.0                  6.749827e+06  2.313757e+07           0.000000
# 74.0                  4.678611e+06  1.431590e+07           0.000000
# 75.0                  2.167541e+06  7.531816e+06           0.000000
# 76.0                  1.904594e+06  5.430135e+06           0.000000
# 77.0                  3.535404e+06  1.749688e+06           0.000000
# 78.0                  4.648627e+06  7.009653e+06           0.000000
# 79.0                  3.759712e+06  1.953112e+07           0.000000
# 80.0                  4.344190e+06  1.251138e+07           0.005063
# 81.0                  2.715956e+06  1.188223e+07           0.000000
# 82.0                  3.893108e+06  1.522091e+07           0.000000
# 83.0                  5.143818e+06  2.163642e+07           0.000000
# 84.0                  2.531727e+06  6.146103e+06           0.015000
# 85.0                  2.747699e+06  8.366379e+06           0.000000
# 86.0                  2.424534e+06  9.480237e+06           0.000000
# 87.0                  3.804861e+06  1.097689e+07           0.000000
# 88.0                  2.995540e+06  7.039769e+06           0.004270
# 89.0                  2.517402e+06  9.600189e+06           0.000000
# 90.0                  3.950777e+06  1.333489e+07           0.040185
# 91.0                  2.872270e+06  8.133248e+06           0.012460
# 92.0                  2.931971e+06  8.427831e+06           0.042953
# 93.0                  2.673026e+06  7.984302e+06           0.044986
# 94.0                  2.777847e+06  8.259646e+06           0.126333
# 95.0                  2.658649e+06  8.075806e+06           0.204908
# 96.0                  2.715489e+06  8.339542e+06           0.423862
# 97.0                  2.625818e+06  8.387864e+06           0.701439
# 98.0                  3.010532e+06  9.594216e+06           0.780096
# 99.0                  3.483346e+06  1.138492e+07           0.794682
# 100.0                 5.057605e+06  1.547857e+07           0.479690
#
#                       accommodates  bathrooms      beds       price  \
# review_scores_rating
# 20.0                      2.000000   1.000000  1.000000  130.000000
# 40.0                      2.285714   1.142857  1.000000   98.714286
# 53.0                      8.000000   1.000000  4.000000  245.000000
# 55.0                      3.000000   1.000000  1.000000  249.000000
# 57.0                      2.000000   1.000000  1.000000   34.000000
# 60.0                      3.809524   1.428571  1.809524  156.000000
# 64.0                      4.000000   1.000000  2.000000  110.000000
# 65.0                      1.000000   1.000000  1.000000   42.000000
# 66.0                      3.500000   1.000000  1.500000   86.500000
# 67.0                      3.000000   1.000000  1.750000  125.625000
# 68.0                      4.200000   1.400000  1.400000  111.000000
# 70.0                      2.500000   1.016667  1.333333  102.933333
# 71.0                      5.950000   1.368421  3.000000  137.350000
# 72.0                      4.666667   0.848485  1.939394  141.212121
# 73.0                      3.576923   1.115385  1.807692  114.115385
# 74.0                      2.428571   1.000000  1.714286  100.714286
# 75.0                      4.259259   1.462963  1.370370  113.333333
# 76.0                      4.341463   1.634146  1.902439  214.487805
# 77.0                      5.418440   1.000000  2.283688  103.695035
# 78.0                      3.068493   1.000000  1.534247   94.082192
# 79.0                      2.000000   1.000000  1.000000   79.975610
# 80.0                      3.597468   1.126582  1.875949  102.081013
# 81.0                      2.107692   1.000000  1.000000   94.276923
# 82.0                      3.481818   1.000000  1.296970   94.069697
# 83.0                      2.670659   1.143713  1.419162   88.437126
# 84.0                      4.231667   1.069167  1.863333  101.750000
# 85.0                      3.082803   1.061306  1.437898   94.398089
# 86.0                      2.921105   1.085799  1.497041   70.729783
# 87.0                      3.715877   1.247110  1.928505  121.982358
# 88.0                      3.598634   1.184885  1.879590  125.456020
# 89.0                      3.057518   1.043210  1.605449   87.642281
# 90.0                      3.661515   1.197579  1.812468  108.947450
# 91.0                      3.247465   1.240655  1.616923  105.410026
# 92.0                      3.609927   1.174992  1.699332  115.842189
# 93.0                      3.191870   1.251785  1.689792  106.276423
# 94.0                      3.045500   1.113250  1.491074  108.191297
# 95.0                      3.080249   1.193058  1.544605  100.228282
# 96.0                      3.026597   1.131705  1.478835  106.548230
# 97.0                      2.956171   1.152444  1.555060  104.307563
# 98.0                      2.969587   1.136479  1.533666  111.889330
# 99.0                      2.766643   1.149512  1.347323  118.731368
# 100.0                     3.281690   1.329863  1.675444  136.895897
#
#                       weekly_price  monthly_price  security_deposit  ...  \
# review_scores_rating                                                 ...
# 20.0                    900.000000       4.000000        200.000000  ...
# 40.0                           NaN            NaN        200.000000  ...
# 53.0                      1.000000       5.000000        100.000000  ...
# 55.0                      1.000000       7.000000               NaN  ...
# 57.0                           NaN            NaN               NaN  ...
# 60.0                    440.312500       2.461538        167.750000  ...
# 64.0                    680.000000       1.000000        200.000000  ...
# 65.0                    320.000000       1.000000               NaN  ...
# 66.0                    587.500000       1.000000        100.000000  ...
# 67.0                    809.375000       3.000000               NaN  ...
# 68.0                    695.000000       1.400000        100.000000  ...
# 70.0                    513.400000     129.214286        168.761905  ...
# 71.0                    530.769231       1.000000        155.263158  ...
# 72.0                    315.000000       2.285714        321.739130  ...
# 73.0                    576.666667       1.333333        175.000000  ...
# 74.0                    675.000000       1.000000        100.000000  ...
# 75.0                    443.518519     135.407407        340.740741  ...
# 76.0                    255.666667       3.466667        288.888889  ...
# 77.0                    450.000000       1.000000        191.428571  ...
# 78.0                    741.986301       1.643836        100.000000  ...
# 79.0                           NaN            NaN               NaN  ...
# 80.0                    510.465201      35.370079        208.464286  ...
# 81.0                    728.769231       3.212121               NaN  ...
# 82.0                    534.164706       1.659389        120.535714  ...
# 83.0                    236.277778       2.352113        256.111111  ...
# 84.0                    403.175439     133.282723        159.210526  ...
# 85.0                    340.734694       1.834320        146.572519  ...
# 86.0                    412.483146      37.668539        116.739130  ...
# 87.0                    419.074148      11.799283        271.092308  ...
# 88.0                    404.281188      81.490566        205.785124  ...
# 89.0                    500.001103      78.946970        182.684932  ...
# 90.0                    420.837607      57.549234        197.507805  ...
# 91.0                    416.664711      40.427474        205.317321  ...
# 92.0                    542.845727      43.331194        214.907074  ...
# 93.0                    315.630090      43.092415        212.873476  ...
# 94.0                    415.824431      66.868443        191.463217  ...
# 95.0                    476.639600      39.574558        219.215701  ...
# 96.0                    447.202936      24.533039        223.447594  ...
# 97.0                    493.914361      37.948269        223.566075  ...
# 98.0                    507.741140      25.136915        237.984272  ...
# 99.0                    500.949282       2.534316        246.426778  ...
# 100.0                   491.232327      22.982759        248.336486  ...
#
#                       room_type_Private room  room_type_Shared room  \
# review_scores_rating
# 20.0                                0.000000               0.000000
# 40.0                                0.142857               0.000000
# 53.0                                0.000000               0.000000
# 55.0                                0.000000               0.000000
# 57.0                                1.000000               0.000000
# 60.0                                0.380952               0.000000
# 64.0                                0.000000               0.000000
# 65.0                                1.000000               0.000000
# 66.0                                0.000000               0.000000
# 67.0                                0.000000               0.000000
# 68.0                                0.000000               0.000000
# 70.0                                0.000000               0.133333
# 71.0                                0.050000               0.000000
# 72.0                                0.303030               0.000000
# 73.0                                0.423077               0.000000
# 74.0                                0.000000               0.000000
# 75.0                                0.148148               0.000000
# 76.0                                0.268293               0.000000
# 77.0                                0.163121               0.000000
# 78.0                                0.000000               0.000000
# 79.0                                0.207317               0.000000
# 80.0                                0.465823               0.048101
# 81.0                                0.000000               0.000000
# 82.0                                0.190909               0.000000
# 83.0                                0.592814               0.000000
# 84.0                                0.220000               0.010000
# 85.0                                0.095541               0.093949
# 86.0                                0.800789               0.000000
# 87.0                                0.256267               0.108635
# 88.0                                0.311699               0.004270
# 89.0                                0.336529               0.011604
# 90.0                                0.294693               0.053065
# 91.0                                0.475225               0.009852
# 92.0                                0.328985               0.023863
# 93.0                                0.433604               0.023668
# 94.0                                0.324448               0.041532
# 95.0                                0.430853               0.003896
# 96.0                                0.320378               0.000937
# 97.0                                0.442164               0.003113
# 98.0                                0.311481               0.024330
# 99.0                                0.366860               0.024964
# 100.0                               0.292305               0.018167
#
#                       bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# review_scores_rating
# 20.0                        0.000000        0.000000                0.000000
# 40.0                        0.000000        0.000000                0.000000
# 53.0                        0.000000        0.000000                0.000000
# 55.0                        0.000000        0.000000                0.000000
# 57.0                        0.000000        0.000000                0.000000
# 60.0                        0.000000        0.000000                0.000000
# 64.0                        0.000000        0.000000                0.000000
# 65.0                        0.000000        0.000000                0.000000
# 66.0                        0.000000        0.000000                0.000000
# 67.0                        0.000000        0.000000                0.000000
# 68.0                        0.000000        0.000000                0.000000
# 70.0                        0.000000        0.000000                0.000000
# 71.0                        0.000000        0.000000                0.000000
# 72.0                        0.000000        0.000000                0.000000
# 73.0                        0.000000        0.192308                0.000000
# 74.0                        0.000000        0.000000                0.000000
# 75.0                        0.000000        0.000000                0.000000
# 76.0                        0.000000        0.000000                0.000000
# 77.0                        0.000000        0.000000                0.000000
# 78.0                        0.000000        0.000000                0.000000
# 79.0                        0.000000        0.207317                0.000000
# 80.0                        0.002532        0.015190                0.000000
# 81.0                        0.000000        0.000000                0.000000
# 82.0                        0.000000        0.000000                0.163636
# 83.0                        0.000000        0.000000                0.000000
# 84.0                        0.000000        0.000000                0.000000
# 85.0                        0.000000        0.062102                0.000000
# 86.0                        0.000000        0.000000                0.000000
# 87.0                        0.000000        0.118849                0.041783
# 88.0                        0.000000        0.000000                0.017079
# 89.0                        0.000000        0.020686                0.019173
# 90.0                        0.000000        0.001030                0.001030
# 91.0                        0.000000        0.000000                0.052159
# 92.0                        0.004454        0.018136                0.011772
# 93.0                        0.000000        0.006323                0.020958
# 94.0                        0.000868        0.033474                0.003595
# 95.0                        0.000000        0.011784                0.009836
# 96.0                        0.000000        0.019760                0.006556
# 97.0                        0.001346        0.033230                0.007319
# 98.0                        0.000000        0.021036                0.022387
# 99.0                        0.000000        0.010130                0.000000
# 100.0                       0.005103        0.016738                0.004082
#
#                       bed_type_Real Bed  cancellation_policy_moderate  \
# review_scores_rating
# 20.0                           1.000000                      0.000000
# 40.0                           1.000000                      0.000000
# 53.0                           1.000000                      1.000000
# 55.0                           1.000000                      0.000000
# 57.0                           1.000000                      1.000000
# 60.0                           1.000000                      0.333333
# 64.0                           1.000000                      0.000000
# 65.0                           1.000000                      0.000000
# 66.0                           1.000000                      1.000000
# 67.0                           1.000000                      0.000000
# 68.0                           1.000000                      0.600000
# 70.0                           1.000000                      0.400000
# 71.0                           1.000000                      0.000000
# 72.0                           1.000000                      0.000000
# 73.0                           0.807692                      0.230769
# 74.0                           1.000000                      0.714286
# 75.0                           0.851852                      0.148148
# 76.0                           1.000000                      0.682927
# 77.0                           1.000000                      0.794326
# 78.0                           1.000000                      0.657534
# 79.0                           0.792683                      0.000000
# 80.0                           0.982278                      0.210127
# 81.0                           1.000000                      0.107692
# 82.0                           0.836364                      0.181818
# 83.0                           1.000000                      0.491018
# 84.0                           1.000000                      0.325000
# 85.0                           0.937898                      0.248408
# 86.0                           1.000000                      0.396450
# 87.0                           0.839369                      0.271123
# 88.0                           0.982921                      0.292058
# 89.0                           0.960141                      0.265893
# 90.0                           0.997939                      0.376095
# 91.0                           0.939438                      0.293248
# 92.0                           0.956729                      0.372574
# 93.0                           0.958808                      0.484914
# 94.0                           0.952021                      0.474709
# 95.0                           0.966887                      0.402707
# 96.0                           0.971905                      0.494475
# 97.0                           0.958105                      0.495836
# 98.0                           0.956577                      0.452480
# 99.0                           0.986614                      0.453871
# 100.0                          0.972239                      0.358236
#
#                       cancellation_policy_strict            id   reviewer_id
# review_scores_rating
# 20.0                                    1.000000  5.588075e+07  4.822953e+06
# 40.0                                    0.142857  4.729153e+07  1.644084e+07
# 53.0                                    0.000000  3.906382e+07  2.491053e+07
# 55.0                                    1.000000  4.672878e+07  2.977111e+07
# 57.0                                    0.000000  5.417516e+07  2.277901e+07
# 60.0                                    0.523810  4.653291e+07  2.319294e+07
# 64.0                                    1.000000  4.081960e+07  2.410462e+07
# 65.0                                    1.000000  2.482139e+07  1.477835e+07
# 66.0                                    0.000000  1.846165e+07  1.410345e+07
# 67.0                                    0.000000  5.061426e+07  2.717342e+07
# 68.0                                    0.400000  2.796612e+07  1.997057e+07
# 70.0                                    0.600000  3.166616e+07  1.407044e+07
# 71.0                                    0.350000  2.613204e+07  1.731965e+07
# 72.0                                    0.696970  3.620459e+07  2.064451e+07
# 73.0                                    0.230769  4.122484e+07  2.146906e+07
# 74.0                                    0.000000  3.277392e+07  1.696394e+07
# 75.0                                    0.185185  4.425662e+07  2.464548e+07
# 76.0                                    0.317073  2.512258e+07  1.679420e+07
# 77.0                                    0.205674  3.791355e+07  2.125951e+07
# 78.0                                    0.342466  3.629172e+07  2.321126e+07
# 79.0                                    0.792683  3.462068e+07  1.992691e+07
# 80.0                                    0.627848  3.645026e+07  1.991491e+07
# 81.0                                    0.892308  3.015100e+07  1.598633e+07
# 82.0                                    0.581818  3.313280e+07  2.004107e+07
# 83.0                                    0.299401  3.805154e+07  1.963624e+07
# 84.0                                    0.611667  2.771777e+07  1.595732e+07
# 85.0                                    0.687898  2.667860e+07  1.588520e+07
# 86.0                                    0.447732  2.768447e+07  1.698839e+07
# 87.0                                    0.621170  3.293605e+07  1.815582e+07
# 88.0                                    0.624253  2.977821e+07  1.657460e+07
# 89.0                                    0.628153  2.799872e+07  1.601610e+07
# 90.0                                    0.469861  3.538782e+07  1.929507e+07
# 91.0                                    0.570849  3.091165e+07  1.782593e+07
# 92.0                                    0.431435  3.056637e+07  1.705720e+07
# 93.0                                    0.394399  2.841788e+07  1.623592e+07
# 94.0                                    0.388173  2.965622e+07  1.650349e+07
# 95.0                                    0.430366  2.907989e+07  1.636616e+07
# 96.0                                    0.379191  2.932145e+07  1.645268e+07
# 97.0                                    0.346092  2.886459e+07  1.626989e+07
# 98.0                                    0.306074  3.057584e+07  1.666768e+07
# 99.0                                    0.309696  3.359613e+07  1.794411e+07
# 100.0                                   0.419882  3.951403e+07  2.096668e+07
#
# [42 rows x 45 columns]

# %%
df_rating=df_clean.copy()

# %%
df_rating['review_scores_rating'].describe()
# Out:
# count    84829.000000
# mean        94.896368
# std          4.084989
# min         20.000000
# 25%         93.000000
# 50%         96.000000
# 75%         98.000000
# max        100.000000
# Name: review_scores_rating, dtype: float64

# %%
bin_edges=[20,93,96,98,100]
bin_names=['Low','Medium','High','Very_High']
df_rating['bin']=pd.cut(df_rating['review_scores_rating'], bin_edges, labels=bin_names)

# %%
rating_mean=df_rating.groupby(['bin']).agg('mean')

# %%
df_rating.columns
# Out:
# Index(['listing_id', 'host_id', 'host_since', 'host_is_superhost',
#        'accommodates', 'bathrooms', 'beds', 'price', 'weekly_price',
#        'monthly_price', 'security_deposit', 'cleaning_fee', 'has_availability',
#        'number_of_reviews', 'first_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month',
#        'property_type_Bed & Breakfast', 'property_type_Boat',
#        'property_type_Bungalow', 'property_type_Cabin',
#        'property_type_Camper/RV', 'property_type_Chalet',
#        'property_type_Condominium', 'property_type_Dorm',
#        'property_type_House', 'property_type_Loft', 'property_type_Other',
#        'property_type_Tent', 'property_type_Townhouse',
#        'property_type_Treehouse', 'property_type_Yurt',
#        'room_type_Private room', 'room_type_Shared room', 'bed_type_Couch',
#        'bed_type_Futon', 'bed_type_Pull-out Sofa', 'bed_type_Real Bed',
#        'cancellation_policy_moderate', 'cancellation_policy_strict', 'id',
#        'date', 'reviewer_id', 'reviewer_name', 'comments', 'bin'],
#       dtype='object')

# %%
rating_mean[['host_is_superhost','accommodates', 'bathrooms', 'beds', 'price', 'weekly_price',
       'monthly_price', 'security_deposit', 'cleaning_fee', 'number_of_reviews', 'review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value', 'reviews_per_month']]
# Out:
#            host_is_superhost  accommodates  bathrooms      beds       price  \
# bin
# Low                 0.024140      3.376552   1.183866  1.690376  106.273806
# Medium              0.263650      3.050841   1.148732  1.505515  104.768268
# High                0.740685      2.962865   1.144465  1.544385  108.090457
# Very_High           0.646686      3.008631   1.234248  1.501487  127.265752
#
#            weekly_price  monthly_price  security_deposit  cleaning_fee  \
# bin
# Low          427.885213      44.802240        199.855541     49.653966
# Medium       450.448599      42.532551        212.776533     46.725947
# High         500.303524      31.773625        230.873686     45.074184
# Very_High    496.187215      12.376720        247.361403     54.484452
#
#            number_of_reviews  review_scores_rating  review_scores_accuracy  \
# bin
# Low                73.399261             89.589430                9.190111
# Medium            100.571970             95.090032                9.779436
# High               97.212527             97.498946                9.969019
# Very_High          48.461974             99.469838                9.972641
#
#            review_scores_cleanliness  review_scores_checkin  \
# bin
# Low                         9.018695               9.572108
# Medium                      9.714773               9.942231
# High                        9.911061               9.987102
# Very_High                   9.963922               9.989631
#
#            review_scores_communication  review_scores_location  \
# bin
# Low                           9.572747                9.319208
# Medium                        9.959534                9.577864
# High                          9.985247                9.761802
# Very_High                     9.988295                9.879919
#
#            review_scores_value  reviews_per_month
# bin
# Low                   8.968841           3.225222
# Medium                9.472081           3.893784
# High                  9.836537           3.806399
# Very_High             9.928962           3.191174

# %%
rating_mean[['property_type_Bed & Breakfast', 'property_type_Boat',
       'property_type_Bungalow', 'property_type_Cabin',
       'property_type_Camper/RV', 'property_type_Chalet',
       'property_type_Condominium', 'property_type_Dorm',
       'property_type_House', 'property_type_Loft', 'property_type_Other',
       'property_type_Tent', 'property_type_Townhouse',
       'property_type_Treehouse', 'property_type_Yurt',
       'room_type_Private room', 'room_type_Shared room', 'bed_type_Couch',
       'bed_type_Futon', 'bed_type_Pull-out Sofa', 'bed_type_Real Bed',
       'cancellation_policy_moderate', 'cancellation_policy_strict']]
# Out:
#            property_type_Bed & Breakfast  property_type_Boat  \
# bin
# Low                             0.005724            0.000277
# Medium                          0.009031            0.000000
# High                            0.019137            0.002318
# Very_High                       0.005179            0.000575
#
#            property_type_Bungalow  property_type_Cabin  \
# bin
# Low                      0.000000             0.008216
# Medium                   0.001379             0.003688
# High                     0.001012             0.067021
# Very_High                0.000959             0.006617
#
#            property_type_Camper/RV  property_type_Chalet  \
# bin
# Low                       0.006000              0.000046
# Medium                    0.005549              0.000379
# High                      0.012940              0.000000
# Very_High                 0.003836              0.000000
#
#            property_type_Condominium  property_type_Dorm  property_type_House  \
# bin
# Low                         0.011078            0.001015             0.431018
# Medium                      0.009203            0.000000             0.473666
# High                        0.005142            0.000000             0.485458
# Very_High                   0.010070            0.000000             0.565071
#
#            property_type_Loft  ...  property_type_Treehouse  \
# bin                            ...
# Low                  0.009370  ...                 0.000923
# Medium               0.040638  ...                 0.000000
# High                 0.010538  ...                 0.000000
# Very_High            0.017167  ...                 0.000959
#
#            property_type_Yurt  room_type_Private room  room_type_Shared room  \
# bin
# Low                  0.000000                0.369351               0.026587
# Medium               0.000000                0.360609               0.013270
# High                 0.000000                0.376960               0.013699
# Very_High            0.002398                0.331831               0.021770
#
#            bed_type_Couch  bed_type_Futon  bed_type_Pull-out Sofa  \
# bin
# Low              0.000692        0.015232                0.022709
# Medium           0.000241        0.020750                0.006894
# High             0.000674        0.027146                0.014837
# Very_High        0.002398        0.013235                0.001918
#
#            bed_type_Real Bed  cancellation_policy_moderate  \
# bin
# Low                 0.954997                      0.361228
# Medium              0.964601                      0.456501
# High                0.957343                      0.474203
# Very_High           0.979860                      0.408938
#
#            cancellation_policy_strict
# bin
# Low                          0.504500
# Medium                       0.399800
# High                         0.326125
# Very_High                    0.361465
#
# [4 rows x 23 columns]

# %%
df_corr=df_rating[['price', 'weekly_price','monthly_price', 'security_deposit', 'cleaning_fee']]
sns.heatmap(df_corr.corr(), annot=True, fmt='.2f');

# %% [markdown]
# ## Linear Regression

# %%
df_lr=df_rating.copy()

# %%
df_lr.isnull().sum()
# Out:
# listing_id                           0
# host_id                              0
# host_since                           2
# host_is_superhost                    0
# accommodates                         0
# bathrooms                          613
# beds                                 1
# price                                0
# weekly_price                     38905
# monthly_price                    49232
# security_deposit                 43110
# cleaning_fee                     23801
# has_availability                     0
# number_of_reviews                    0
# first_review                       627
# review_scores_rating               647
# review_scores_accuracy             661
# review_scores_cleanliness          654
# review_scores_checkin              661
# review_scores_communication        652
# review_scores_location             658
# review_scores_value                659
# reviews_per_month                  627
# property_type_Bed & Breakfast        0
# property_type_Boat                   0
# property_type_Bungalow               0
# property_type_Cabin                  0
# property_type_Camper/RV              0
# property_type_Chalet                 0
# property_type_Condominium            0
# property_type_Dorm                   0
# property_type_House                  0
# property_type_Loft                   0
# property_type_Other                  0
# property_type_Tent                   0
# property_type_Townhouse              0
# property_type_Treehouse              0
# property_type_Yurt                   0
# room_type_Private room               0
# room_type_Shared room                0
# bed_type_Couch                       0
# bed_type_Futon                       0
# bed_type_Pull-out Sofa               0
# bed_type_Real Bed                    0
# cancellation_policy_moderate         0
# cancellation_policy_strict           0
# id                                 627
# date                               627
# reviewer_id                        627
# reviewer_name                      627
# comments                           645
# bin                                648
# dtype: int64

# %%
df_lr=df_lr.dropna(subset=['first_review','review_scores_rating','review_scores_accuracy',
                             'review_scores_cleanliness','review_scores_checkin',
                             'review_scores_communication','review_scores_location',
                             'review_scores_value','reviews_per_month','id','date','reviewer_id',
                             'reviewer_name','comments','bin','bathrooms','host_since','beds'], axis=0)

# %%
df_lr=df_lr.fillna(method='ffill')

# %%
df_lr=df_lr.fillna(method='bfill')

# %%
df_lr.isnull().sum()
# Out:
# listing_id                       0
# host_id                          0
# host_since                       0
# host_is_superhost                0
# accommodates                     0
# bathrooms                        0
# beds                             0
# price                            0
# weekly_price                     0
# monthly_price                    0
# security_deposit                 0
# cleaning_fee                     0
# has_availability                 0
# number_of_reviews                0
# first_review                     0
# review_scores_rating             0
# review_scores_accuracy           0
# review_scores_cleanliness        0
# review_scores_checkin            0
# review_scores_communication      0
# review_scores_location           0
# review_scores_value              0
# reviews_per_month                0
# property_type_Bed & Breakfast    0
# property_type_Boat               0
# property_type_Bungalow           0
# property_type_Cabin              0
# property_type_Camper/RV          0
# property_type_Chalet             0
# property_type_Condominium        0
# property_type_Dorm               0
# property_type_House              0
# property_type_Loft               0
# property_type_Other              0
# property_type_Tent               0
# property_type_Townhouse          0
# property_type_Treehouse          0
# property_type_Yurt               0
# room_type_Private room           0
# room_type_Shared room            0
# bed_type_Couch                   0
# bed_type_Futon                   0
# bed_type_Pull-out Sofa           0
# bed_type_Real Bed                0
# cancellation_policy_moderate     0
# cancellation_policy_strict       0
# id                               0
# date                             0
# reviewer_id                      0
# reviewer_name                    0
# comments                         0
# bin                              0
# dtype: int64

# %%
def find_optimal_lm_mod(X, y, cutoffs, test_size = .30, random_state=42, plot=True):
    '''
    INPUT
    X - pandas dataframe, X matrix
    y - pandas dataframe, response variable
    cutoffs - list of ints, cutoff for number of non-zero values in dummy categorical vars
    test_size - float between 0 and 1, default 0.3, determines the proportion of data as test data
    random_state - int, default 42, controls random state for train_test_split
    plot - boolean, default 0.3, True to plot result

    OUTPUT
    r2_scores_test - list of floats of r2 scores on the test data
    r2_scores_train - list of floats of r2 scores on the train data
    lm_model - model object from sklearn
    X_train, X_test, y_train, y_test - output from sklearn train test split used for optimal model
    '''
    r2_scores_test, r2_scores_train, num_feats, results = [], [], [], dict()
    for cutoff in cutoffs:

        #reduce X matrix
        reduce_X = X.iloc[:, np.where((X.sum() > cutoff) == True)[0]]
        num_feats.append(reduce_X.shape[1])

        #split the data into train and test
        X_train, X_test, y_train, y_test = train_test_split(reduce_X, y, test_size = test_size, random_state=random_state)

        #fit the model and obtain pred response
        lm_model = LinearRegression(normalize=True)
        lm_model.fit(X_train, y_train)
        y_test_preds = lm_model.predict(X_test)
        y_train_preds = lm_model.predict(X_train)

        #append the r2 value from the test set
        r2_scores_test.append(r2_score(y_test, y_test_preds))
        r2_scores_train.append(r2_score(y_train, y_train_preds))
        results[str(cutoff)] = r2_score(y_test, y_test_preds)

    if plot:
        plt.plot(num_feats, r2_scores_test, label="Test", alpha=.5)
        plt.plot(num_feats, r2_scores_train, label="Train", alpha=.5)
        plt.xlabel('Number of Features')
        plt.ylabel('Rsquared')
        plt.title('Rsquared by Number of Features')
        plt.legend(loc=1)
        plt.show()

    best_cutoff = max(results, key=results.get)

    #reduce X matrix
    reduce_X = X.iloc[:, np.where((X.sum() > int(best_cutoff)) == True)[0]]
    num_feats.append(reduce_X.shape[1])

    #split the data into train and test
    X_train, X_test, y_train, y_test = train_test_split(reduce_X, y, test_size = test_size, random_state=random_state)

    #fit the model
    lm_model = LinearRegression(normalize=True)
    lm_model.fit(X_train, y_train)

    return r2_scores_test, r2_scores_train, lm_model, X_train, X_test, y_train, y_test

X=df_lr
y=df_lr.review_scores_rating

cutoffs = [5000, 3500, 2500, 1000, 100, 50, 30, 25]

# %%
r2_scores_test, r2_scores_train, lm_model, X_train, X_test, 
y_train, y_test = find_optimal_lm_mod(X, y, cutoffs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-76e4cfa98c89> in <module>
# ----> 1 r2_scores_test, r2_scores_train, lm_model, X_train, X_test,
#       2 y_train, y_test = find_optimal_lm_mod(X, y, cutoffs)
#
# NameError: name 'r2_scores_test' is not defined
